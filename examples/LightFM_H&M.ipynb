# %%
import sys
sys.path.append("c:/users/david/desktop/sandbox")
import pandas as pd
import numpy as np
from pyrecs.train import lightfm_wrapper

# %load_ext autoreload
# %autoreload 2
# Out:
# C:\Users\David\Desktop\Sandbox\pyrecs\env\lib\site-packages\lightfm\_lightfm_fast.py:9: UserWarning: LightFM was compiled without OpenMP support. Only a single thread will be used.
#   warnings.warn(

# %% [markdown]
# # Pure CF

# %%
df = pd.read_csv('../data/h&m/transactions_train_with_dates.csv')
df.drop_duplicates(['customer_id', 'article_id'], keep='first', inplace=True)

for col in ['customer_id','article_id']:
    df[col] = df[col].astype(str)
    
print(df.shape)
df.head()
# Out:
# (27306439, 9)
#         t_dat                                        customer_id article_id  \
# 0  2018-09-20  000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...  663713001
# 1  2018-09-20  000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...  541518023
# 2  2018-09-20  00007d2de826758b65a93dd24ce629ed66842531df6699...  505221004
# 3  2018-09-20  00007d2de826758b65a93dd24ce629ed66842531df6699...  685687003
# 4  2018-09-20  00007d2de826758b65a93dd24ce629ed66842531df6699...  685687004
#
#       price  sales_channel_id  t_dat_year  t_dat_week  customer_ind  \
# 0  0.050831                 2        2018          38             0
# 1  0.030492                 2        2018          38             0
# 2  0.015237                 2        2018          38             1
# 3  0.016932                 2        2018          38             1
# 4  0.016932                 2        2018          38             1
#
#    article_ind
# 0            0
# 1            1
# 2            2
# 3            3
# 4            4

# %%
train_df = df[~((df['t_dat_year']==2020) & (df['t_dat_week'].isin([38,39])))].copy()
test_df = df[(df['t_dat_year']==2020) & (df['t_dat_week'].isin([38,39]))].copy()

train_df.shape, test_df.shape
# Out:
# ((27053842, 9), (252597, 9))

# %%
train_df['customer_id'].nunique(), test_df['customer_id'].nunique(), len(set(train_df['customer_id'].unique()) & set(test_df['customer_id'].unique()))
# Out:
# (1355461, 80430, 73610)

# %%
train_df['article_id'].nunique(), test_df['article_id'].nunique(), len(set(train_df['article_id'].unique()) & set(test_df['article_id'].unique()))
# Out:
# (103629, 19177, 18259)

# %%
df.dtypes
# Out:
# t_dat                object
# customer_id          object
# article_id           object
# price               float64
# sales_channel_id      int64
# t_dat_year            int64
# t_dat_week            int64
# customer_ind          int64
# article_ind           int64
# dtype: object

# %%
model_kwargs = {
    'no_components':30,
    'learning_rate':0.05,
    'loss':'warp',
    'random_state':42
}
train_kwargs = {
    'num_epochs':2,
    'num_threads':1,
    'eval_epochs':'all',
    'plot':True
}
lfm = lightfm_wrapper.LightFM(users_col='customer_id', items_col='article_id', interactions_type='ones',
                              model_kwargs=model_kwargs, train_kwargs=train_kwargs,
                              n_recs=12, tfrs_prediction_batch_size=512)

# %%
lfm.run(train_df=train_df, test_df=test_df)
# Out:
# Training:   0%|                                                                                  | 0/2 [32:56<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
# ----> 1 lfm.run(train_df=train_df, test_df=test_df)
#
# File c:\users/david/desktop/sandbox\pyrecs\train\lightfm_wrapper.py:246, in LightFM.run(self, train_df, test_df, train_user_features_dict, train_item_features_dict, test_user_features_dict, test_item_features_dict)
#     240 def run(self,
#     241         train_df, test_df,
#     242         train_user_features_dict={}, train_item_features_dict={},
#     243         test_user_features_dict={}, test_item_features_dict={}):
#     244     self.preprocess(train_df, test_df, train_user_features_dict, train_item_features_dict,
#     245                     test_user_features_dict, test_item_features_dict)
# --> 246     self.train()
#
# File c:\users/david/desktop/sandbox\pyrecs\train\lightfm_wrapper.py:219, in LightFM.train(self)
#     211 self.model.fit_partial(interactions=ones_interactions_matrix,
#     212                        user_features=self.train_user_features_matrix,
#     213                        item_features=self.train_item_features_matrix,
#     214                        sample_weight=self.interactions_matrix,
#     215                        epochs=1, num_threads=self.train_kwargs['num_threads'],
#     216                        verbose=False)
#     217 if (self.train_kwargs['eval_epochs'] == 'all') or (epoch in self.train_kwargs['eval_epochs']):
#     218     # Evaluate results
# --> 219     train_mapk, test_mapk = self.evaluate(save_predictions = (epoch==self.train_kwargs['num_epochs']))
#     220     self.eval_epochs.append(epoch)
#     221     self.train_evaluations.append(train_mapk)
#
# File c:\users/david/desktop/sandbox\pyrecs\train\lightfm_wrapper.py:184, in LightFM.evaluate(self, save_predictions)
#     179 item_identifiers = train_item_identifiers+test_item_identifiers
#     181 # Predict
#     182 # TODO: Add functionality to filter out items that users have already interacted with in train
#     183 # TODO: Predict most popular items for new users, when we don't have user features and can't represent those new users
# --> 184 predictions_dict = tfrs_streaming.predict(user_identifiers=user_identifiers,
#     185                                           user_embeddings=user_embeddings,
#     186                                           item_identifiers=item_identifiers,
#     187                                           item_embeddings=item_embeddings,
#     188                                           embedding_dtype='float32',
#     189                                           n_recs=self.n_recs,
#     190                                           prediction_batch_size=self.tfrs_prediction_batch_size)
#     191 if save_predictions:
#     192     self.predictions_dict = predictions_dict
#
# File c:\users/david/desktop/sandbox\pyrecs\predict\tfrs_streaming.py:31, in predict(user_identifiers, user_embeddings, item_identifiers, item_embeddings, embedding_dtype, n_recs, prediction_batch_size)
#      29 # Format predictions
#      30 formatted_predictions = []
# ---> 31 for n, candidate_ids in enumerate(itertools.chain(*predictions.as_numpy_iterator())):
#      32     formatted_predictions.append((user_identifiers[n],
#      33                                   candidate_ids.flatten().astype(str).tolist()))
#      35 return dict(formatted_predictions)
#
# File ~\Desktop\Sandbox\pyrecs\env\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:4407, in _NumpyIterator.__next__(self)
#    4404     numpy.setflags(write=False)
#    4405   return numpy
# -> 4407 return nest.map_structure(to_numpy, next(self._iterator))
#
# File ~\Desktop\Sandbox\pyrecs\env\lib\site-packages\tensorflow\python\data\ops\iterator_ops.py:836, in OwnedIterator.__next__(self)
#     834 def __next__(self):
#     835   try:
# --> 836     return self._next_internal()
#     837   except errors.OutOfRangeError:
#     838     raise StopIteration
#
# File ~\Desktop\Sandbox\pyrecs\env\lib\site-packages\tensorflow\python\data\ops\iterator_ops.py:819, in OwnedIterator._next_internal(self)
#     816 # TODO(b/77291417): This runs in sync mode as iterators use an error status
#     817 # to communicate that there is no more data to iterate over.
#     818 with context.execution_mode(context.SYNC):
# --> 819   ret = gen_dataset_ops.iterator_get_next(
#     820       self._iterator_resource,
#     821       output_types=self._flat_output_types,
#     822       output_shapes=self._flat_output_shapes)
#     824   try:
#     825     # Fast path for the case `self._structure` is not a nested structure.
#     826     return self._element_spec._from_compatible_tensor_list(ret)  # pylint: disable=protected-access
#
# File ~\Desktop\Sandbox\pyrecs\env\lib\site-packages\tensorflow\python\ops\gen_dataset_ops.py:2917, in iterator_get_next(iterator, output_types, output_shapes, name)
#    2915 if tld.is_eager:
#    2916   try:
# -> 2917     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    2918       _ctx, "IteratorGetNext", name, iterator, "output_types", output_types,
#    2919       "output_shapes", output_shapes)
#    2920     return _result
#    2921   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
lfm.train_evaluations, lfm.test_evaluations
